# %%
import pandas as pd

# %%
df = pd.read_csv('data_clean.csv')

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
df.shape
# Out:
# (158, 10)

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
df.isna().sum()
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar.R        7
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
del df['Unnamed: 0']

# %%
del df['Temp C']

# %%
df
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     5    1  2010    67       S
# 1     36.0    118.0   8.0     5    2  2010    72       C
# 2     12.0    149.0  12.6     5    3  2010    74      PS
# 3     18.0    313.0  11.5     5    4  2010    62       S
# 4      NaN      NaN  14.3     5    5  2010    56       S
# ..     ...      ...   ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     5    1  2010    67       C
# 154   30.0    193.0   6.9     9   26  2010    70      PS
# 155    NaN    145.0  13.2     9   27  2010    77       S
# 156   14.0    191.0  14.3     9   28  2010    75       S
# 157   18.0    131.0   8.0     9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
df['Ozone'].fillna(df['Ozone'].mean(), inplace=True)
# Out:
# C:\Users\anbuu\AppData\Local\Temp\ipykernel_27228\3790871892.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Ozone'].fillna(df['Ozone'].mean(), inplace=True)

# %%
df['Solar.R'].fillna(df['Solar.R'].mean(), inplace=True)
# Out:
# C:\Users\anbuu\AppData\Local\Temp\ipykernel_27228\1792264423.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Solar.R'].fillna(df['Solar.R'].mean(), inplace=True)

# %%
weather_mode = df['Weather'].mode()
weather_mode
# Out:
# 0    S
# Name: Weather, dtype: object

# %%
df['Weather'].fillna(weather_mode.item(), inplace=True)
# Out:
# C:\Users\anbuu\AppData\Local\Temp\ipykernel_27228\687647254.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Weather'].fillna(weather_mode.item(), inplace=True)

# %%
df.isna().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
df['Month'] = df['Month'].replace(to_replace='May', value=5)

# %%
df['Month'] = pd.to_numeric(df['Month'])

# %%
df.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month        int64
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %% [markdown]
# # Label Encoding, One Hot Encoding

# %%
df_1 = df.copy()

# %%
df_2 = df.copy()

# %%
df_3 = df.copy()

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/11.1 MB 10.5 MB/s eta 0:00:01
#    --------------- ------------------------ 4.2/11.1 MB 12.0 MB/s eta 0:00:01
#    ------------------- -------------------- 5.5/11.1 MB 9.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.3/11.1 MB 8.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/11.1 MB 7.4 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.1 MB 5.8 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.1 MB 5.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.9/11.1 MB 4.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.1/11.1 MB 4.5 MB/s eta 0:00:01
#    ------------------------------- -------- 8.7/11.1 MB 4.2 MB/s eta 0:00:01
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df_1['Weather'] = le.fit_transform(df_1['Weather'])

# %%
df_1.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month        int64
# Day          int64
# Year         int64
# Temp         int64
# Weather      int64
# dtype: object

# %%
df_1
# Out:
#          Ozone     Solar.R  Wind  Month  Day  Year  Temp  Weather
# 0    41.000000  190.000000   7.4      5    1  2010    67        2
# 1    36.000000  118.000000   8.0      5    2  2010    72        0
# 2    12.000000  149.000000  12.6      5    3  2010    74        1
# 3    18.000000  313.000000  11.5      5    4  2010    62        2
# 4    41.583333  185.403974  14.3      5    5  2010    56        2
# ..         ...         ...   ...    ...  ...   ...   ...      ...
# 153  41.000000  190.000000   7.4      5    1  2010    67        0
# 154  30.000000  193.000000   6.9      9   26  2010    70        1
# 155  41.583333  145.000000  13.2      9   27  2010    77        2
# 156  14.000000  191.000000  14.3      9   28  2010    75        2
# 157  18.000000  131.000000   8.0      9   29  2010    76        0
#
# [158 rows x 8 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ONE = OneHotEncoder()

# %%
df_2[['Weather_C', 'Weather_PS', 'Weather_S']] = ONE.fit_transform(df[['Weather']]).toarray().astype('int')

# %%
df_2
# Out:
#          Ozone     Solar.R  Wind  Month  Day  Year  Temp Weather  Weather_C  \
# 0    41.000000  190.000000   7.4      5    1  2010    67       S          0
# 1    36.000000  118.000000   8.0      5    2  2010    72       C          1
# 2    12.000000  149.000000  12.6      5    3  2010    74      PS          0
# 3    18.000000  313.000000  11.5      5    4  2010    62       S          0
# 4    41.583333  185.403974  14.3      5    5  2010    56       S          0
# ..         ...         ...   ...    ...  ...   ...   ...     ...        ...
# 153  41.000000  190.000000   7.4      5    1  2010    67       C          1
# 154  30.000000  193.000000   6.9      9   26  2010    70      PS          0
# 155  41.583333  145.000000  13.2      9   27  2010    77       S          0
# 156  14.000000  191.000000  14.3      9   28  2010    75       S          0
# 157  18.000000  131.000000   8.0      9   29  2010    76       C          1
#
#      Weather_PS  Weather_S
# 0             0          1
# ...

# %%
df_3 = pd.get_dummies(data=df, columns=['Weather'])  # This convert it into bool data type

# %%
df_3['Weather_C'] = df_3['Weather_C'].astype(int)
df_3['Weather_PS'] = df_3['Weather_C'].astype(int)
df_3['Weather_S'] = df_3['Weather_C'].astype(int)

# %%
df_3
# Out:
#          Ozone     Solar.R  Wind  Month  Day  Year  Temp  Weather_C  \
# 0    41.000000  190.000000   7.4      5    1  2010    67          0
# 1    36.000000  118.000000   8.0      5    2  2010    72          1
# 2    12.000000  149.000000  12.6      5    3  2010    74          0
# 3    18.000000  313.000000  11.5      5    4  2010    62          0
# 4    41.583333  185.403974  14.3      5    5  2010    56          0
# ..         ...         ...   ...    ...  ...   ...   ...        ...
# 153  41.000000  190.000000   7.4      5    1  2010    67          1
# 154  30.000000  193.000000   6.9      9   26  2010    70          0
# 155  41.583333  145.000000  13.2      9   27  2010    77          0
# 156  14.000000  191.000000  14.3      9   28  2010    75          0
# 157  18.000000  131.000000   8.0      9   29  2010    76          1
#
#      Weather_PS  Weather_S
# 0             0          0
# 1             1          1
# 2             0          0
# 3             0          0
# ...
