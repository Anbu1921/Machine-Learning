# %%
# !pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 7.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
df = pd.read_excel('Online Retail.xlsx')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df['Description'].value_counts()
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    2369
# REGENCY CAKESTAND 3 TIER              2200
# JUMBO BAG RED RETROSPOT               2159
# PARTY BUNTING                         1727
# LUNCH BAG RED RETROSPOT               1638
#                                       ...
# Marked as 23343                          1
# 20713                                    1
# HEAVENS SCENT FRAGRANCE OILS ASSTD       1
# BLUE DROP EARRINGS W BEAD CLUSTER        1
# PURPLE ANEMONE ARTIFICIAL FLOWER         1
# Name: count, Length: 4223, dtype: int64

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df['Country'].nunique()
# Out:
# 38

# %%
df['Country'].value_counts()
# Out:
# Country
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
France_df = df[df['Country']=='France']

# %%
France_df.reset_index(drop=True, inplace=True)

# %%
France_df
# Out:
#      InvoiceNo StockCode                      Description  Quantity  \
# 0       536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 1       536370     22727        ALARM CLOCK BAKELIKE RED         24
# 2       536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 3       536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 4       536370     21883                 STARS GIFT TAPE         24
# ...        ...       ...                              ...       ...
# 8552    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 8553    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 8554    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 8555    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 8556    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID Country
# 0    2010-12-01 08:45:00       3.75     12583.0  France
# ...

# %%
pivot_France_df = pd.pivot_table(data = France_df, index = 'InvoiceNo', columns = 'Description', values='Quantity').fillna(0)
pivot_France_df
# Out:
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536370                                  0.0                 0.0
# 536852                                  0.0                 0.0
# 536974                                  0.0                 0.0
# 537065                                  0.0                 0.0
# 537463                                  0.0                 0.0
# ...                                     ...                 ...
# C579532                                 0.0                 0.0
# C579562                                 0.0                 0.0
# C580161                                 0.0                 0.0
# C580263                                 0.0                 0.0
# C581316                                 0.0                 0.0
#
# Description   I LOVE LONDON MINI BACKPACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536370                                0.0                       0.0
# ...

# %%
encoded_France_df = pivot_France_df.map(lambda x:1 if x>0 else 0)

# %%
frequent_dataset = apriori(encoded_France_df, min_support=0.05, verbose=1, use_colnames=True)
# Out:
# Processing 140 combinations | Sampling itemset size 43

# %%
frequent_dataset
# Out:
#       support                                           itemsets
# 0    0.060738                      (4 TRADITIONAL SPINNING TOPS)
# 1    0.082430                       (ALARM CLOCK BAKELIKE GREEN)
# 2    0.086768                        (ALARM CLOCK BAKELIKE PINK)
# 3    0.080260                        (ALARM CLOCK BAKELIKE RED )
# 4    0.058568                       (ASSORTED COLOUR MINI CASES)
# ..        ...                                                ...
# 124  0.071584  (SET/6 RED SPOTTY PAPER CUPS, POSTAGE, SET/20 ...
# 125  0.071584  (SET/6 RED SPOTTY PAPER PLATES, POSTAGE, SET/2...
# 126  0.086768  (SET/6 RED SPOTTY PAPER PLATES, POSTAGE, SET/6...
# 127  0.084599  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...
# 128  0.069414  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
#
# [129 rows x 2 columns]

# %%
best_association = association_rules(frequent_dataset, metric='confidence', min_threshold=0.7, num_itemsets=len(frequent_dataset))

# %%
best_association[['antecedents', 'consequents', 'support', 'confidence']]
# Out:
#                                           antecedents  \
# 0                         (ALARM CLOCK BAKELIKE PINK)
# 1                        (ALARM CLOCK BAKELIKE GREEN)
# 2                         (ALARM CLOCK BAKELIKE RED )
# 3                        (ALARM CLOCK BAKELIKE GREEN)
# 4                        (ALARM CLOCK BAKELIKE GREEN)
# ..                                                ...
# 95  (SET/20 RED RETROSPOT PAPER NAPKINS , POSTAGE,...
# 96           (SET/6 RED SPOTTY PAPER PLATES, POSTAGE)
# 97  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 98  (SET/20 RED RETROSPOT PAPER NAPKINS , SET/6 RE...
# 99     (POSTAGE, SET/20 RED RETROSPOT PAPER NAPKINS )
#
#                                           consequents   support  confidence
# 0                        (ALARM CLOCK BAKELIKE GREEN)  0.062907    0.725000
# 1                         (ALARM CLOCK BAKELIKE PINK)  0.062907    0.763158
# 2                        (ALARM CLOCK BAKELIKE GREEN)  0.067245    0.837838
# ...

# %%
best_association['antecedents'][80]
# Out:
# frozenset({'POSTAGE', 'SET/20 RED RETROSPOT PAPER NAPKINS '})
