# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
del iris['species']

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
scalar = StandardScaler()
scaled_iris = scalar.fit_transform(iris)
scaled_iris
# Out:
# array([[-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.16971425e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  7.88807586e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.74885626e+00, -3.62176246e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.44707648e+00],
#        [-5.37177559e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
# ...

# %%
kmeans_cluster = KMeans(n_clusters=3)
kmeans_cluster.fit(scaled_iris)
# Out:
# KMeans(n_clusters=3)

# %%
pred = kmeans_cluster.predict(scaled_iris)

# %%
kmeans_cluster.cluster_centers_
# Out:
# array([[-3.64080601e-01, -1.41450432e+00,  1.07774588e-01,
#          8.77547895e-04],
#        [-5.47274882e-01,  1.99734061e+00, -1.26917974e+00,
#         -1.21672016e+00],
#        [ 9.73381893e-01, -5.52472239e-02,  6.07402636e-01,
#          4.13325059e-01],
#        [-1.39960770e+00, -5.07335618e-02, -1.34022653e+00,
#         -1.32318736e+00],
#        [ 1.00434702e+00,  2.51681798e-01,  1.02484196e+00,
#          1.34645099e+00],
#        [ 3.23114321e-02, -2.12548348e-01,  3.87631252e-01,
#          3.36539618e-01],
#        [ 3.60890187e-01, -8.36110764e-01,  8.22939074e-01,
#          8.60358281e-01],
#        [ 2.08812630e+00, -4.77274629e-01,  1.53006353e+00,
#          1.14168981e+00],
#        [-9.69919953e-01,  9.31310346e-01, -1.29692182e+00,
#         -1.22142131e+00],
#        [ 2.12851559e+00,  1.55613014e+00,  1.50164482e+00,
#          1.36107679e+00]])

# %%
iris['Target'] = pd.DataFrame(data=pred, columns=['Target'])

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Target
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       1
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       1
# 148           6.2          3.4           5.4          2.3       1
# 149           5.9          3.0           5.1          1.8       1
#
# [150 rows x 5 columns]

# %%
iris[iris['Target']==0]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  Target
# 0            5.1          3.5           1.4          0.2       0
# 1            4.9          3.0           1.4          0.2       0
# 2            4.7          3.2           1.3          0.2       0
# 3            4.6          3.1           1.5          0.2       0
# 4            5.0          3.6           1.4          0.2       0
# 5            5.4          3.9           1.7          0.4       0
# 6            4.6          3.4           1.4          0.3       0
# 7            5.0          3.4           1.5          0.2       0
# 8            4.4          2.9           1.4          0.2       0
# 9            4.9          3.1           1.5          0.1       0
# 10           5.4          3.7           1.5          0.2       0
# 11           4.8          3.4           1.6          0.2       0
# 12           4.8          3.0           1.4          0.1       0
# ...

# %%
wcss = [] # Within cluster sum square
for i in range(1, 11):
    kmeans_cluster = KMeans(n_clusters=i)
    kmeans_cluster.fit(scaled_iris)
    wcss.append(kmeans_cluster.inertia_)

# %%
plt.plot(range(1, 11), wcss)
